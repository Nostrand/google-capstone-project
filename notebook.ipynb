# %% [markdown]
# ![ashpokemonbattles](ashpokemonbattles.jpg)
#
# # Data-Driven Merchandise Sales Strategy: Exploring Pokemon Choices

# %% [markdown]
# ## Scenario: Business Task and Objectives
#
# I am a junior data analyst working for a business intelligence consultant. I have been assigned a project for a new client, a retail store specializing in anime and game merchandise. My task is to conduct a data-driven analysis to provide recommendations for curating a compelling lineup of Pokemon merchandise to kickstart the retail store's offerings. The objective is to optimize the selection of Pokemon plushies that will resonate with customers, align with their preferences, and maximize sales potential.
#
# To achieve this, my analysis will consider various factors, including:
#
# 1. Analyzing Ash's Journey and Pokemon Win Rates: By examining Ash's journey in the Pokemon animated series and games, I will identify the Pokemon that have been consistently used by Ash and have achieved high win rates in battles. These Pokemon hold significant popularity and can serve as strong candidates for inclusion in the merchandise lineup.
# 2. Investigating Reddit Survey Data: I will explore data from a Reddit survey that captures the favorite Pokemon of Reddit users. This survey provides valuable insights into the preferences and beloved Pokemon among online communities. Analyzing the survey results will help identify Pokemon that garner significant attention and are highly regarded by fans.
# 3. Examining Japan Survey Data for Pokemon Scarlet/Violet: Additionally, I will investigate data from a Japan survey specifically focused on the favorite Pokemon of players in the Pokemon Scarlet/Violet games. This survey provides insights into the preferences and favorite Pokemon of the Japanese market, which is a significant audience for Pokemon merchandise. Incorporating these findings will help ensure that the pokemon lineup appeals to the Japanese customer base.
# 4. Creating a Ranking of Popularity: A key aspect of this project is to create a comprehensive ranking of Pokemon popularity, this will be derived from the analysis of the datasets obtained from the previous section. By incorporating this fourth objective, we ensure a holistic approach to our analysis, encompassing various factors and capturing the evolving preferences and popularity of Pokemon within different contexts.

# %% [markdown]
# ## Data Sources
# The analysis will involve the following datasets:
#
# - Ash's Pokemon Win Percentages: Kanto-Alola (2020)
#   - This dataset records pokemon captured and used by Ash Ketchup in battles, including both official and unofficial battles, up to gen 7.
#   - Source: [Ash Pokemon rank by win percentage](https://www.deviantart.com/pkmnmasterwheeler/art/Ash-s-Pokemon-Win-Percentages-Kanto-Alola-864961647)
#   -------------------------------------------------------------
#
# - Complete Pokemon dataset (2022)
#   - This comprehensive dataset contains information on pokemon up to generation 9 and was compiled from [pokemondb.net](https://pokemondb.net/pokedex/all).
#   - Source: [Kaggle dataset](https://www.kaggle.com/datasets/brdata/complete-pokemon-dataset-gen-iiv?resource=download)
#   -------------------------------------------------------------
#
# - Reddit's Favourite Pokemon Survey (2019)
#   - This dataset originates from a Reddit survey and includes the favorite pokemon of 52,836 users.
#   - Source: [Reddit's Favourite Pokemon Survey](https://www.reddit.com/r/pokemon/comments/c0w4s0/favourite_pok%C3%A9mon_survey_results/)
#   -------------------------------------------------------------
#
# - Japan's Favorite Pokemon Survey (2022)
#   - This dataset comprises the results of a survey conducted in Japan, highlighting the favorite pokemon among 177,829 respondents.
#   - Source: [Favorite Pokémon in 2022](https://gamewith.jp/pokemon-sv/article/show/381211)
#
# In the 'ash_pokemon_kanto-alola.csv' file, the following information is available:
# - **name:** The name of each pokemon.
# - **battles:** the total number of battles for each pokemon.
# - **wins:** The number of battles won by each pokemon.
# - **losses:** The number of battles lost by each pokemon.
#
# From the 'Pokedex_Cleaned.csv' file, I will import the following information:
# * **type:** The pokemon type for each entry.
#
# From the 'reddit_survey_data.csv' file:
# * **Pokemon:** The name of each pokemon.
# * **Number of votes:** The number of votes received by each pokemon in the survey.
#
# Lastly, from the 'japan_survey_data.csv' file:
# * **name:** The name of each pokemon.
# * **votes:** The number of votes received by each pokemon in the survey.

# %% [markdown]
# ## Data Preparation and Transformation
#
# In this section, several actions were performed to prepare and transform the data for further analysis and recommendation generation. These actions included:
#
# 1. Cleaning and Standardization: I focused on ensuring data integrity and accuracy by checking missing values, handling duplicate entries, and resolving inconsistencies within the dataset.
# 2. Feature Engineering: I derived new features from the Ash Pokemon dataset, including win percentage and a variety of ranks based off different datasets.
# 3. Data Integration: Incorporated the pokemon type data from the pokedex dataset into each respective dataset, to enhance the visualization capabilities.
# 4. Color Palette Setup: I established a color palette based on Pokemon types. This palette will be utilized in the visualization created in a later section, enhancing the visual representation of Pokemon attributes.
# 5. Rank-Based Dataset Creation and Recommendation List: I created a comprehensive dataset that incorporates rankings based on the number of battles, win percentage, Reddit survey votes, and Japan survey votes for each Pokemon. Using this rank-based dataset, I generated a recommendation list that highlights the top-performing Pokemon across various categories. This approach ensures that our recommendations are based on objective criteria and provide valuable insights.

# %%
# Importing libraries
library(tidyverse)

# Loading Ash pokemon data
data_raw <- read.csv("ash_pokemon_kanto-alola.csv")
head(data_raw)

# Loading Pokedex data
pokedex_data <- read.csv("Pokedex_Cleaned.csv", skip = 1, header = FALSE, stringsAsFactors = FALSE)

# Exclude the first column
pokedex_data <- pokedex_data[, -1]
# Remove the additional columns
pokedex_data <- pokedex_data[, 1:2]

# Rename columns
colnames(pokedex_data) <- c("name", "type_1")

# Print the modified dataset
head(pokedex_data)

# Loading Reddit Survey data
reddit_survey_data <- read.csv("reddit_survey_data.csv", skip = 1, header = TRUE)

# Rename columns and drop the ones I don't need
colnames(reddit_survey_data) <- c("name", "votes")
reddit_survey_data <- subset(reddit_survey_data, select = c("name", "votes"))
head(reddit_survey_data)

# Loading Japan Survey data
japan_survey_data <- read.csv("japan_survey_data.csv")
head(japan_survey_data);
# Out:
#   name       battles wins losses
# 1 Pikachu    538     479  59
# 2 Goodra      16      14   2
# 3 Naganadel    7       6   1
# 4 Greninja    55      47   8
# 5 Bayleef     38      32   6
# 6 Incineroar  24      20   4
#   name       type_1
# 1 Bulbasaur  Grass
# 2 Ivysaur    Grass
# 3 Venusaur   Grass
# 4 Venusaur   Grass
# 5 Charmander Fire
# 6 Charmeleon Fire
#   name      votes
# 1 Charizard 1107
# 2 Gengar    1056
# 3 Arcanine   923
# 4 Bulbasaur  710
# 5 Blaziken   613
# 6 Umbreon    607
#   name                 votes
# 1 Tinkaton             7458
# 2 Clodsire             5820
# 3 Meowscarada          5311
# 4 Fuecoco              4464
# 5 Ceruledge            3922
# 6 Tastugiri Curly Form 3059

# %%
# Removing duplicate data
pokedex_data <- pokedex_data[!duplicated(pokedex_data$name), ]

# Merging data
merged_pokemon <- left_join(data_raw, pokedex_data, by= "name") %>%
	select(name, battles, wins, losses, type_1)

# Data preview
head(merged_pokemon)
# Out:
#   name       battles wins losses type_1
# 1 Pikachu    538     479  59     Electric
# 2 Goodra      16      14   2     Dragon
# 3 Naganadel    7       6   1     Poison
# 4 Greninja    55      47   8     Water
# 5 Bayleef     38      32   6     Grass
# 6 Incineroar  24      20   4     Fire

# %%
# Adding another column
ash_pokemon <- merged_pokemon %>% mutate(win_pct = wins / battles)

# Renaming column type_1 to type
ash_pokemon <- ash_pokemon %>% rename(type = type_1)
head(ash_pokemon)
# Out:
#   name       battles wins losses type     win_pct
# 1 Pikachu    538     479  59     Electric 0.8903346
# 2 Goodra      16      14   2     Dragon   0.8750000
# 3 Naganadel    7       6   1     Poison   0.8571429
# 4 Greninja    55      47   8     Water    0.8545455
# 5 Bayleef     38      32   6     Grass    0.8421053
# 6 Incineroar  24      20   4     Fire     0.8333333

# %%
# Check for missing values in each column for all Pokemon
pokemon_with_missing <- apply(ash_pokemon, 1, function(row) any(is.na(row)))

# Subset the dataset to show Pokemon with missing values
pokemon_missing_values <- ash_pokemon[pokemon_with_missing, ]
print(pokemon_missing_values)
# Out:
# [1] name    battles wins    losses  type    win_pct
# <0 rows> (or 0-length row.names)

# %%
# Setting up color palette based on pokemon types
type_colors <- c("Bug" = "#A8B820", "Dark" = "#705848", "Dragon" = "#7038F8", 
                 "Electric" = "#F8D030", "Fairy" = "#EE99AC", "Fighting" = "#C03028", 
                 "Fire" = "#F08030", "Flying" = "#A890F0", "Ghost" = "#705898", 
                 "Grass" = "#78C850", "Ground" = "#E0C068", "Ice" = "#98D8D8", 
                 "Normal" = "#A8A878", "Poison" = "#A040A0", "Psychic" = "#F85888", 
                 "Rock" = "#B8A038", "Steel" = "#B8B8D0", "Water" = "#6890F0")

# %%
# Create a new dataset with ranks for battles and win percentage
new_dataset <- data.frame(
  name = ash_pokemon$name,
  battle_rank = rank(-ash_pokemon$battles, na.last = "keep"),
  win_pct_rank = rank(-ash_pokemon$win_pct, na.last = "keep")
)
# Creating rank for the reddit survey data 
reddit_survey_data$votes_rank <- rank(-reddit_survey_data$votes, na.last = "keep")

# Merging the new dataset with the reddit survey results
new_dataset <- merge(new_dataset, reddit_survey_data[, c("name", "votes_rank")], by = "name", all = TRUE)

# Creating rank for the japan survey data
japan_survey_data$japan_votes_rank <- rank(-japan_survey_data$votes, na.last = "keep")

# Merging the new dataset with the japan survey results
new_dataset <- merge(new_dataset, japan_survey_data[, c("name", "japan_votes_rank")], by = "name", all = TRUE)

# Print the new dataset with ranks
print(new_dataset)
# Out:
#                      name battle_rank win_pct_rank votes_rank japan_votes_rank
# 1               Abomasnow          NA           NA      393.0               NA
# 2                    Abra          NA           NA      120.5               NA
# 3                   Absol          NA           NA       11.0               NA
# 4                Accelgor          NA           NA      494.5               NA
# 5               Aegislash          NA           NA       78.0               NA
# 6              Aerodactyl          NA           NA      233.0               NA
# 7                  Aggron          NA           NA       38.0               NA
# 8                   Aipom        25.5         17.0      196.5               NA
# 9                Alakazam          NA           NA       31.0               NA
# 10              Alomomola          NA           NA      801.5               NA
# 11                Altaria          NA           NA       92.5             43.0
# 12                 Amaura          NA           NA      625.5               NA
# 13                Ambipom          NA           NA      339.5               NA
# 14              Amoonguss          NA           NA      733.5               NA
# 15               Ampharos          NA           NA       13.0             45.0
# 16                Anorith          NA           NA      625.5               NA
# 17              Araquanid          NA           NA      393.0               NA
# 18                  Arbok          NA           NA      467.0               NA
# 19               Arcanine          NA           NA        3.0             36.0
# 20                 Arceus          NA           NA      303.5               NA
# 21                 Archen          NA           NA      583.5               NA
# 22               Archeops          NA           NA      252.5               NA
# 23                Ariados          NA           NA      529.5               NA
# 24                Armaldo          NA           NA      386.0               NA
# 25             Aromatisse          NA           NA      604.5               NA
# 26                   Aron          NA           NA      134.0               NA
# 27               Articuno          NA           NA       92.5               NA
# 28                 Audino          NA           NA      311.5               NA
# 29                Aurorus          NA           NA      467.0               NA
# 30                Avalugg          NA           NA      583.5               NA
# 31                   Axew          NA           NA      485.5               NA
# 32                  Azelf          NA           NA      529.5               NA
# 33              Azumarill          NA           NA      124.5             41.0
# 34                Azurill          NA           NA      583.5               NA
# 35                  Bagon          NA           NA      485.5               NA
# 36                 Baltoy          NA           NA      801.5               NA
# 37                Banette          NA           NA      165.0               NA
# 38             Barbaracle          NA           NA      547.0               NA
# 39               Barboach          NA           NA      783.5               NA
# 40               Basculin          NA           NA      704.0               NA
# 41              Bastiodon          NA           NA      467.0               NA
# 42                Bayleef        10.0          5.0      196.5               NA
# 43                Beartic          NA           NA      583.5               NA
# 44              Beautifly          NA           NA      783.5               NA
# 45               Beedrill          NA           NA      154.0               NA
# 46               Beheeyem          NA           NA      453.5               NA
# 47                 Beldum          NA           NA      453.5               NA
# 48              Bellossom          NA           NA      365.0               NA
# 49             Bellsprout          NA           NA      376.0               NA
# 50               Bergmite          NA           NA      648.0               NA
# 51                 Bewear          NA           NA      299.0               NA
# 52                Bibarel          NA           NA      625.5               NA
# 53                 Bidoof          NA           NA      161.5               NA
# 54                Binacle          NA           NA      783.5               NA
# 55                Bisharp          NA           NA      140.0               NA
# 56            Blacephalon          NA           NA      625.5               NA
# 57              Blastoise          NA           NA       23.0               NA
# 58               Blaziken          NA           NA        5.0               NA
# 59                Blissey          NA           NA      504.0               NA
# 60                Blitzle          NA           NA      733.5               NA
# 61                Boldore          NA           NA      673.0               NA
# 62                 Bonsly          NA           NA      648.0               NA
# 63             Bouffalant          NA           NA      704.0               NA
# 64              Bounsweet          NA           NA      757.5               NA
# 65                Braixen          NA           NA      252.5               NA
# 66               Braviary          NA           NA      320.5               NA
# 67                Breloom          NA           NA       62.0               NA
# 68                Brionne          NA           NA      673.0               NA
# 69               Bronzong          NA           NA      437.5               NA
# 70                Bronzor          NA           NA      673.0               NA
# 71                Bruxish          NA           NA      583.5               NA
# 72                  Budew          NA           NA      648.0               NA
# 73                 Buizel         8.0         39.0      144.0               NA
# 74              Bulbasaur         3.0         12.0        4.0               NA
# 75                Buneary          NA           NA      494.5               NA
# 76               Bunnelby          NA           NA      783.5               NA
# 77                  Burmy          NA           NA      648.0               NA
# 78             Butterfree        32.0         33.0      214.5               NA
# 79               Buzzwole          NA           NA      467.0               NA
# 80                 Cacnea          NA           NA      410.5               NA
# 81               Cacturne          NA           NA      437.5               NA
# 82               Camerupt          NA           NA      269.5               NA
# 83                Carbink          NA           NA      564.0               NA
# 84              Carnivine          NA           NA      547.0               NA
# 85             Carracosta          NA           NA      453.5               NA
# 86               Carvanha          NA           NA      757.5               NA
# 87                Cascoon          NA           NA      783.5               NA
# 88               Castform          NA           NA      299.0               NA
# 89               Caterpie          NA           NA      365.0               NA
# 90                 Celebi          NA           NA      172.0               NA
# 91             Celesteela          NA           NA      625.5               NA
# 92              Ceruledge          NA           NA         NA              5.0
# 93             Chandelure          NA           NA       64.0               NA
# 94                Chansey          NA           NA      228.5               NA
# 95              Charizard         5.5         21.0        1.0             25.0
# 96              Charjabug          NA           NA      604.5               NA
# 97             Charmander          NA           NA       32.0               NA
# 98             Charmeleon          NA           NA      188.0               NA
# 99                 Chatot          NA           NA      339.5               NA
# 100               Cherrim          NA           NA      410.5               NA
# 101               Cherubi          NA           NA      625.5               NA
# 102            Chesnaught          NA           NA      453.5               NA
# 103               Chespin          NA           NA      356.5               NA
# 104             Chikorita          NA           NA      130.0               NA
# 105              Chimchar          NA           NA      188.0               NA
# 106              Chimecho          NA           NA      393.0               NA
# 107              Chinchou          NA           NA      437.5               NA
# 108             Chingling          NA           NA      673.0               NA
# 109              Cinccino          NA           NA      279.0               NA
# 110              Clamperl          NA           NA      625.5               NA
# 111             Clauncher          NA           NA      783.5               NA
# 112             Clawitzer          NA           NA      529.5               NA
# 113               Claydol          NA           NA      467.0               NA
# 114              Clefable          NA           NA      283.0               NA
# 115              Clefairy          NA           NA      261.0               NA
# 116                Cleffa          NA           NA      673.0               NA
# 117              Clodsire          NA           NA         NA              2.0
# 118              Cloyster          NA           NA      219.5               NA
# 119              Cobalion          NA           NA      648.0               NA
# 120            Cofagrigus          NA           NA      294.5               NA
# 121                Combee          NA           NA      514.0               NA
# 122             Combusken          NA           NA      673.0               NA
# 123                Comfey          NA           NA      704.0               NA
# 124            Conkeldurr          NA           NA      504.0               NA
# 125              Corphish         5.5         26.0      494.5               NA
# 126               Corsola          NA           NA      311.5               NA
# 127               Cosmoem          NA           NA      801.5               NA
# 128                Cosmog          NA           NA      583.5               NA
# 129              Cottonee          NA           NA      783.5               NA
# 130          Crabominable          NA           NA      783.5               NA
# 131            Crabrawler          NA           NA      704.0               NA
# 132               Cradily          NA           NA      252.5               NA
# 133              Cranidos          NA           NA      604.5               NA
# 134             Crawdaunt          NA           NA      348.0               NA
# 135             Cresselia          NA           NA      604.5               NA
# 136              Croagunk          NA           NA      246.0               NA
# 137                Crobat          NA           NA       61.0               NA
# 138              Croconaw          NA           NA      437.5               NA
# 139               Crustle          NA           NA      437.5               NA
# 140             Cryogonal          NA           NA      494.5               NA
# 141               Cubchoo          NA           NA      625.5               NA
# 142                Cubone          NA           NA       36.0               NA
# 143              Cutiefly          NA           NA      410.5               NA
# 144             Cyndaquil          NA           NA       30.0               NA
# 145               Darkrai          NA           NA       71.5               NA
# 146            Darmanitan          NA           NA      330.0               NA
# 147               Dartrix          NA           NA      783.5               NA
# 148              Darumaka          NA           NA      583.5               NA
# 149             Decidueye          NA           NA      123.0               NA
# 150               Dedenne          NA           NA      365.0               NA
# 151              Deerling          NA           NA      704.0               NA
# 152                 Deino          NA           NA      529.5               NA
# 153              Delcatty          NA           NA      348.0               NA
# 154              Delibird          NA           NA      288.5               NA
# 155               Delphox          NA           NA      275.5               NA
# 156                Deoxys          NA           NA      175.5               NA
# 157               Dewgong          NA           NA      243.5               NA
# 158                Dewott          NA           NA      233.0               NA
# 159              Dewpider          NA           NA      783.5               NA
# 160              Dhelmise          NA           NA      399.0               NA
# 161                Dialga          NA           NA      180.0               NA
# 162               Diancie          NA           NA      494.5               NA
# 163             Diggersby          NA           NA      733.5               NA
# 164               Diglett          NA           NA      248.0               NA
# 165                 Ditto          NA           NA       73.0             33.0
# 166                Dodrio          NA           NA      514.0               NA
# 167                 Doduo          NA           NA      648.0               NA
# 168               Donphan        27.0         13.0      182.5               NA
# 169              Doublade          NA           NA      583.5               NA
# 170              Dragalge          NA           NA      399.0               NA
# 171             Dragapult          NA           NA         NA             21.0
# 172             Dragonair          NA           NA       84.5               NA
# 173             Dragonite          NA           NA       10.0             46.0
# 174                Drampa          NA           NA      504.0               NA
# 175               Drapion          NA           NA      269.5               NA
# 176               Dratini          NA           NA      141.0               NA
# 177              Drifblim          NA           NA      311.5               NA
# 178              Drifloon          NA           NA      185.0               NA
# 179               Drilbur          NA           NA      704.0               NA
# 180               Drowzee          NA           NA      478.5               NA
# 181             Druddigon          NA           NA      485.5               NA
# 182              Ducklett          NA           NA      583.5               NA
# 183               Dugtrio          NA           NA      386.0               NA
# 184             Dunsparce          NA           NA       68.0               NA
# 185               Duosion          NA           NA      783.5               NA
# 186                Durant          NA           NA      529.5               NA
# 187              Dusclops          NA           NA      423.5               NA
# 188              Dusknoir          NA           NA      269.5               NA
# 189               Duskull          NA           NA      261.0               NA
# 190                Dustox          NA           NA      704.0               NA
# 191               Dwebble          NA           NA      648.0               NA
# 192             Eelektrik          NA           NA      807.5               NA
# 193            Eelektross          NA           NA      243.5               NA
# 194                 Eevee          NA           NA        9.0             28.0
# 195                 Ekans          NA           NA      604.5               NA
# 196            Electabuzz          NA           NA      269.5               NA
# 197            Electivire          NA           NA      117.0               NA
# 198             Electrike          NA           NA      625.5               NA
# 199             Electrode          NA           NA      529.5               NA
# 200                Elekid          NA           NA      410.5               NA
# 201                Elgyem          NA           NA      547.0               NA
# 202                Emboar          NA           NA      288.5               NA
# 203                Emolga          NA           NA      252.5               NA
# 204              Empoleon          NA           NA       33.0               NA
# 205                 Entei          NA           NA      219.5               NA
# 206            Escavalier          NA           NA      393.0               NA
# 207                Espeon          NA           NA       28.0             48.0
# 208                Espurr          NA           NA      216.5               NA
# 209             Excadrill          NA           NA      275.5               NA
# 210             Exeggcute          NA           NA      801.5               NA
# 211             Exeggutor          NA           NA      238.5               NA
# 212               Exploud          NA           NA      386.0               NA
# 213             Farfetchd          NA           NA      110.0               NA
# 214                Fearow          NA           NA      437.5               NA
# 215                Feebas          NA           NA      673.0               NA
# 216              Fennekin          NA           NA      410.5               NA
# 217            Feraligatr          NA           NA       46.0               NA
# 218             Ferroseed          NA           NA      757.5               NA
# 219            Ferrothorn          NA           NA      283.0               NA
# 220               Fidough          NA           NA         NA             35.0
# 221               Finneon          NA           NA      625.5               NA
# 222               Flaaffy          NA           NA      264.5               NA
# 223               Flabebe          NA           NA      733.5               NA
# 224               Flareon          NA           NA      138.5               NA
# 225           Fletchinder          NA           NA      604.5               NA
# 226            Fletchling          NA           NA      673.0               NA
# 227              Floatzel          NA           NA      269.5               NA
# 228               Floette          NA           NA      704.0               NA
# 229               Florges          NA           NA      704.0               NA
# 230          Flutter Mane          NA           NA         NA             38.0
# 231                Flygon          NA           NA       15.0               NA
# 232              Fomantis          NA           NA      757.5               NA
# 233               Foongus          NA           NA      704.0               NA
# 234            Forretress          NA           NA      348.0               NA
# 235               Fraxure          NA           NA      673.0               NA
# 236              Frillish          NA           NA      783.5               NA
# 237               Froakie          NA           NA      564.0               NA
# 238             Frogadier          NA           NA      757.5               NA
# 239              Froslass          NA           NA       88.0               NA
# 240               Fuecoco          NA           NA         NA              4.0
# 241               Furfrou          NA           NA      547.0               NA
# 242                Furret          NA           NA       97.5               NA
# 243                Gabite          NA           NA      604.5               NA
# 244               Gallade          NA           NA       58.0               NA
# 245            Galvantula          NA           NA      113.0               NA
# 246              Garbodor          NA           NA      348.0               NA
# 247              Garchomp          NA           NA       24.5             22.0
# 248             Gardevoir          NA           NA        8.0             10.5
# 249                Gastly          NA           NA      376.0               NA
# 250             Gastrodon          NA           NA      248.0               NA
# 251              Genesect          NA           NA      365.0               NA
# 252                Gengar          NA           NA        2.0             13.0
# 253               Geodude          NA           NA      288.5               NA
# 254                 Gible        45.0         24.5      303.5               NA
# 255              Gigalith          NA           NA      485.5               NA
# 256             Girafarig          NA           NA      311.5               NA
# 257              Giratina          NA           NA       84.5               NA
# 258               Glaceon          NA           NA       75.0             20.0
# 259                Glalie        39.5         15.0      311.5               NA
# 260               Glameow          NA           NA      757.5               NA
# 261                Gligar          NA           NA      348.0               NA
# 262              Glimmora          NA           NA         NA             37.0
# 263               Gliscor        36.5         48.5       97.5               NA
# 264                 Gloom          NA           NA      330.0               NA
# 265                Gogoat          NA           NA      294.5               NA
# 266                Golbat          NA           NA      547.0               NA
# 267               Goldeen          NA           NA      783.5               NA
# 268               Golduck          NA           NA      210.0               NA
# 269                 Golem          NA           NA      257.0               NA
# 270                Golett          NA           NA      625.5               NA
# 271             Golisopod          NA           NA      169.5               NA
# 272                Golurk          NA           NA      146.0               NA
# 273                Goodra        28.0          2.0      151.0               NA
# 274                 Goomy          NA           NA      228.5             42.0
# 275              Gorebyss          NA           NA      648.0               NA
# 276               Gothita          NA           NA      807.5               NA
# 277            Gothitelle          NA           NA      494.5               NA
# 278             Gothorita          NA           NA      704.0               NA
# 279             Gourgeist          NA           NA      399.0               NA
# 280              Granbull          NA           NA      625.5               NA
# 281              Graveler          NA           NA      514.0               NA
# 282              Greninja         2.0          4.0       66.0               NA
# 283                Grimer          NA           NA      514.0               NA
# 284                Grotle          NA           NA      564.0               NA
# 285               Groudon          NA           NA      207.0               NA
# 286               Grovyle          NA           NA       99.0               NA
# 287             Growlithe          NA           NA       51.0               NA
# 288               Grubbin          NA           NA      704.0               NA
# 289               Grumpig          NA           NA      437.5               NA
# 290                Gulpin          NA           NA      494.5               NA
# 291              Gumshoos          NA           NA      733.5               NA
# 292               Gurdurr          NA           NA      757.5               NA
# 293              Guzzlord          NA           NA      504.0               NA
# 294              Gyarados          NA           NA       54.5               NA
# 295              Hakamo-O          NA           NA      733.5               NA
# 296               Happiny          NA           NA      704.0               NA
# 297              Hariyama          NA           NA      529.5               NA
# 298               Haunter          NA           NA       40.5               NA
# 299              Hawlucha        13.5         28.5      199.5               NA
# 300               Haxorus          NA           NA      116.0               NA
# 301               Heatmor          NA           NA      673.0               NA
# 302               Heatran          NA           NA      648.0               NA
# 303             Heliolisk          NA           NA      393.0               NA
# 304            Helioptile          NA           NA      564.0               NA
# 305             Heracross        32.0         33.0       50.0               NA
# 306               Herdier          NA           NA      648.0               NA
# 307            Hippopotas          NA           NA      673.0               NA
# 308             Hippowdon          NA           NA      547.0               NA
# 309            Hitmonchan          NA           NA      230.0               NA
# 310             Hitmonlee          NA           NA      257.0               NA
# 311             Hitmontop          NA           NA      485.5               NA
# 312                 Ho-Oh          NA           NA      243.5               NA
# 313             Honchkrow          NA           NA      177.5               NA
# 314               Honedge          NA           NA      365.0               NA
# 315                 Hoopa          NA           NA      625.5               NA
# 316              Hoothoot          NA           NA      625.5               NA
# 317                Hoppip          NA           NA      514.0               NA
# 318                Horsea          NA           NA      604.5               NA
# 319              Houndoom          NA           NA       76.0               NA
# 320              Houndour          NA           NA      356.5               NA
# 321               Huntail          NA           NA      783.5               NA
# 322             Hydreigon          NA           NA       80.0             23.0
# 323                 Hypno          NA           NA      339.5               NA
# 324             Igglybuff          NA           NA      704.0               NA
# 325              Illumise          NA           NA      704.0               NA
# 326            Incineroar        20.0          6.5      214.5               NA
# 327             Infernape         7.0          9.0       18.0               NA
# 328                 Inkay          NA           NA      437.5               NA
# 329          Iron Valiant          NA           NA         NA             27.0
# 330               Ivysaur          NA           NA      154.0               NA
# 331              Jangmo-O          NA           NA      757.5               NA
# 332             Jellicent          NA           NA      410.5               NA
# 333            Jigglypuff          NA           NA       82.0               NA
# 334               Jirachi          NA           NA      104.5               NA
# 335               Jolteon          NA           NA       35.0               NA
# 336                Joltik          NA           NA      169.5               NA
# 337              Jumpluff          NA           NA      303.5               NA
# 338                  Jynx          NA           NA      288.5               NA
# 339                Kabuto          NA           NA      453.5               NA
# 340              Kabutops          NA           NA      110.0               NA
# 341               Kadabra          NA           NA      158.5               NA
# 342                Kakuna          NA           NA      529.5               NA
# 343            Kangaskhan          NA           NA      294.5               NA
# 344            Karrablast          NA           NA      783.5               NA
# 345               Kartana          NA           NA      564.0               NA
# 346               Kecleon          NA           NA      365.0               NA
# 347                Keldeo          NA           NA      514.0               NA
# 348               Kingdra          NA           NA      182.5               NA
# 349               Kingler        42.5         20.0      203.5               NA
# 350                Kirlia          NA           NA      478.5               NA
# 351                 Klang          NA           NA      733.5               NA
# 352                Klefki          NA           NA      261.0               NA
# 353                 Klink          NA           NA      704.0               NA
# 354             Klinklang          NA           NA      330.0               NA
# 355               Koffing          NA           NA      203.5               NA
# 356                Komala          NA           NA      529.5               NA
# 357               Kommo-O          NA           NA      514.0               NA
# 358              Koraidon          NA           NA         NA             12.0
# 359                Krabby          NA           NA      269.5               NA
# 360             Kricketot          NA           NA      604.5               NA
# 361            Kricketune          NA           NA      514.0               NA
# 362              Krokorok          NA           NA      583.5               NA
# 363            Krookodile        30.0         38.0      136.5               NA
# 364                Kyogre          NA           NA      185.0               NA
# 365                Kyurem          NA           NA      437.5               NA
# 366                Lairon          NA           NA      467.0               NA
# 367               Lampent          NA           NA      547.0               NA
# 368              Landorus          NA           NA      783.5               NA
# 369               Lanturn          NA           NA      201.0               NA
# 370                Lapras        48.5         24.5       60.0               NA
# 371              Larvesta          NA           NA      467.0               NA
# 372              Larvitar          NA           NA      238.5               NA
# 373                Latias          NA           NA      131.5               NA
# 374                Latios          NA           NA      193.5               NA
# 375               Leafeon          NA           NA      101.0             40.0
# 376              Leavanny        34.5         22.0      453.5               NA
# 377                Ledian          NA           NA      348.0               NA
# 378                Ledyba          NA           NA      704.0               NA
# 379            Lickilicky          NA           NA      467.0               NA
# 380             Lickitung          NA           NA      223.0               NA
# 381               Liepard          NA           NA      583.5               NA
# 382                Lileep          NA           NA      733.5               NA
# 383             Lilligant          NA           NA      138.5               NA
# 384              Lillipup          NA           NA      733.5               NA
# 385               Linoone          NA           NA      339.5               NA
# 386                Litleo          NA           NA      733.5               NA
# 387                Litten          NA           NA      339.5               NA
# 388               Litwick          NA           NA      210.0               NA
# 389                Lombre          NA           NA      673.0               NA
# 390               Lopunny          NA           NA      161.5               NA
# 391                 Lotad          NA           NA      311.5               NA
# 392               Loudred          NA           NA      704.0               NA
# 393               Lucario          NA           NA        7.0              9.0
# 394              Ludicolo          NA           NA       87.0               NA
# 395                 Lugia          NA           NA       56.0               NA
# 396              Lumineon          NA           NA      547.0               NA
# 397                Lunala          NA           NA      564.0               NA
# 398              Lunatone          NA           NA      625.5               NA
# 399              Lurantis          NA           NA      386.0               NA
# 400               Luvdisc          NA           NA      604.5               NA
# 401                 Luxio          NA           NA      478.5               NA
# 402                Luxray          NA           NA       21.0             26.0
# 403              Lycanroc        17.5         10.0      142.5               NA
# 404               Machamp          NA           NA      127.0               NA
# 405               Machoke          NA           NA      410.5               NA
# 406                Machop          NA           NA      410.5               NA
# 407                 Magby          NA           NA      704.0               NA
# 408              Magcargo          NA           NA      410.5               NA
# 409              Magearna          NA           NA      648.0               NA
# 410              Magikarp          NA           NA      107.0               NA
# 411                Magmar          NA           NA      269.5               NA
# 412             Magmortar          NA           NA      386.0               NA
# 413             Magnemite          NA           NA      207.0               NA
# 414              Magneton          NA           NA      226.0               NA
# 415             Magnezone          NA           NA      223.0               NA
# 416              Makuhita          NA           NA      733.5               NA
# 417               Malamar          NA           NA      320.5               NA
# 418             Mamoswine          NA           NA      191.0               NA
# 419               Manaphy          NA           NA      376.0               NA
# 420             Mandibuzz          NA           NA      529.5               NA
# 421             Manectric          NA           NA      203.5               NA
# 422                Mankey          NA           NA      437.5               NA
# 423               Mantine          NA           NA      376.0               NA
# 424               Mantyke          NA           NA      583.5               NA
# 425              Maractus          NA           NA      216.5               NA
# 426              Mareanie          NA           NA      529.5               NA
# 427                Mareep          NA           NA      110.0               NA
# 428                Marill          NA           NA      339.5               NA
# 429               Marowak          NA           NA      154.0               NA
# 430             Marshadow          NA           NA      356.5               NA
# 431             Marshtomp          NA           NA      437.5               NA
# 432            Masquerain          NA           NA      399.0               NA
# 433              Maushold          NA           NA         NA             17.5
# 434                Mawile          NA           NA       57.0               NA
# 435              Medicham          NA           NA      453.5               NA
# 436              Meditite          NA           NA      783.5               NA
# 437              Meganium          NA           NA      175.5               NA
# 438              Melmetal        36.5         11.0      529.5               NA
# 439              Meloetta          NA           NA      299.0               NA
# 440                Meltan          NA           NA      757.5               NA
# 441           Meowscarada          NA           NA         NA              3.0
# 442              Meowstic          NA           NA      257.0               NA
# 443                Meowth          NA           NA      238.5               NA
# 444               Mesprit          NA           NA      704.0               NA
# 445             Metagross          NA           NA       26.0               NA
# 446                Metang          NA           NA      625.5               NA
# 447               Metapod          NA           NA      478.5               NA
# 448                   Mew          NA           NA       53.0               NA
# 449                Mewtwo          NA           NA       43.0               NA
# 450               Mienfoo          NA           NA      757.5               NA
# 451              Mienshao          NA           NA      356.5               NA
# 452             Mightyena          NA           NA      207.0               NA
# 453               Milotic          NA           NA       63.0               NA
# 454               Miltank          NA           NA      226.0               NA
# 455               Mime-Jr          NA           NA      604.5               NA
# 456               Mimikyu          NA           NA       47.0             10.5
# 457              Minccino          NA           NA      410.5               NA
# 458                Minior          NA           NA      330.0               NA
# 459                 Minun          NA           NA      399.0               NA
# 460              Miraidon          NA           NA         NA             17.5
# 461            Misdreavus          NA           NA      165.0               NA
# 462             Mismagius          NA           NA      165.0               NA
# 463               Moltres          NA           NA      494.5               NA
# 464              Monferno          NA           NA      376.0               NA
# 465              Morelull          NA           NA      704.0               NA
# 466                Mothim          NA           NA      648.0               NA
# 467               Mr-Mime          NA           NA      188.0               NA
# 468               Mudbray          NA           NA      704.0               NA
# 469                Mudkip          NA           NA       24.5               NA
# 470              Mudsdale          NA           NA      514.0               NA
# 471                   Muk        48.5         48.5      148.5               NA
# 472              Munchlax          NA           NA      238.5               NA
# 473                 Munna          NA           NA      733.5               NA
# 474               Murkrow          NA           NA      148.5               NA
# 475              Musharna          NA           NA      648.0               NA
# 476             Naganadel        42.5          3.0      604.5               NA
# 477                  Natu          NA           NA      423.5               NA
# 478              Necrozma          NA           NA      410.5               NA
# 479              Nidoking          NA           NA       54.5               NA
# 480             Nidoqueen          NA           NA      410.5               NA
# 481             Nidoran-F          NA           NA      648.0               NA
# 482             Nidoran-M          NA           NA      478.5               NA
# 483              Nidorina          NA           NA      673.0               NA
# 484              Nidorino          NA           NA      410.5               NA
# 485              Nihilego          NA           NA      564.0               NA
# 486               Nincada          NA           NA      757.5               NA
# 487             Ninetales          NA           NA       16.0               NA
# 488               Ninjask          NA           NA      376.0               NA
# 489               Noctowl        32.0         33.0      330.0               NA
# 490                Noibat          NA           NA      529.5               NA
# 491               Noivern        34.5         44.0      114.5               NA
# 492              Nosepass          NA           NA      583.5               NA
# 493                 Numel          NA           NA      437.5               NA
# 494               Nuzleaf          NA           NA      673.0               NA
# 495             Octillery          NA           NA      294.5               NA
# 496                Oddish          NA           NA      101.0               NA
# 497               Omanyte          NA           NA      504.0               NA
# 498               Omastar          NA           NA      529.5               NA
# 499                  Onix          NA           NA      252.5               NA
# 500              Oranguru          NA           NA      673.0               NA
# 501              Oricorio          NA           NA      564.0               NA
# 502              Oshawott        17.5         42.0      154.0               NA
# 503             Pachirisu          NA           NA      279.0               NA
# 504                Palkia          NA           NA      311.5               NA
# 505             Palossand          NA           NA      604.5               NA
# 506             Palpitoad        45.0         44.0      733.5               NA
# 507               Pancham          NA           NA      453.5               NA
# 508               Pangoro          NA           NA      365.0               NA
# 509               Panpour          NA           NA      783.5               NA
# 510               Pansage          NA           NA      673.0               NA
# 511               Pansear          NA           NA      783.5               NA
# 512                 Paras          NA           NA      423.5               NA
# 513              Parasect          NA           NA      330.0               NA
# 514             Passimian          NA           NA      648.0               NA
# 515                Patrat          NA           NA      801.5               NA
# 516                 Pawmi          NA           NA         NA             19.0
# 517                Pawmot          NA           NA         NA             15.0
# 518              Pawniard          NA           NA      673.0               NA
# 519              Pelipper          NA           NA      348.0               NA
# 520               Persian          NA           NA      320.5               NA
# 521               Petilil          NA           NA      648.0               NA
# 522                Phanpy          NA           NA      173.5               NA
# 523              Phantump          NA           NA      365.0               NA
# 524             Pheromosa          NA           NA      583.5               NA
# 525                Phione          NA           NA      783.5               NA
# 526                 Pichu          NA           NA      212.5               NA
# 527               Pidgeot        29.0         46.0      134.0               NA
# 528             Pidgeotto          NA           NA      330.0               NA
# 529                Pidgey          NA           NA      269.5               NA
# 530                Pidove          NA           NA      648.0               NA
# 531               Pignite        11.0         27.0      648.0               NA
# 532               Pikachu         1.0          1.0       44.0             31.0
# 533               Pikipek          NA           NA      757.5               NA
# 534             Piloswine          NA           NA      529.5               NA
# 535                Pineco          NA           NA      648.0               NA
# 536                Pinsir          NA           NA      330.0               NA
# 537                Piplup          NA           NA       70.0               NA
# 538                Plusle          NA           NA      410.5               NA
# 539               Poipole          NA           NA      604.5               NA
# 540              Politoed          NA           NA      180.0               NA
# 541               Poliwag          NA           NA      348.0               NA
# 542             Poliwhirl          NA           NA      134.0               NA
# 543             Poliwrath          NA           NA      219.5               NA
# 544                Ponyta          NA           NA      233.0               NA
# 545             Poochyena          NA           NA      365.0               NA
# 546               Popplio          NA           NA      386.0               NA
# 547               Porygon          NA           NA      131.5               NA
# 548             Porygon-Z          NA           NA       86.0               NA
# 549              Porygon2          NA           NA      191.0               NA
# 550             Primarina          NA           NA      233.0               NA
# 551              Primeape        45.0          6.5      212.5               NA
# 552              Prinplup          NA           NA      564.0               NA
# 553             Probopass          NA           NA      494.5               NA
# 554               Psyduck          NA           NA       49.0               NA
# 555             Pumpkaboo          NA           NA      311.5               NA
# 556               Pupitar          NA           NA      783.5               NA
# 557              Purrloin          NA           NA      757.5               NA
# 558               Purugly          NA           NA      583.5               NA
# 559                Pyroar          NA           NA      467.0               NA
# 560             Pyukumuku          NA           NA      243.5               NA
# 561              Quagsire          NA           NA      104.5             30.0
# 562             Quaquaval          NA           NA         NA             32.0
# 563               Quilava        22.5         30.5       74.0               NA
# 564             Quilladin          NA           NA      757.5               NA
# 565              Qwilfish          NA           NA      410.5               NA
# 566                Raichu          NA           NA       40.5               NA
# 567                Raikou          NA           NA      275.5               NA
# 568                 Ralts          NA           NA      158.5               NA
# 569             Rampardos          NA           NA      423.5               NA
# 570              Rapidash          NA           NA      173.5               NA
# 571              Raticate          NA           NA      467.0               NA
# 572               Rattata          NA           NA      376.0               NA
# 573              Rayquaza          NA           NA       37.0               NA
# 574                Regice          NA           NA      564.0               NA
# 575             Regigigas          NA           NA      356.5               NA
# 576              Regirock          NA           NA      673.0               NA
# 577             Registeel          NA           NA      494.5               NA
# 578             Relicanth          NA           NA      330.0               NA
# 579              Remoraid          NA           NA      757.5               NA
# 580              Reshiram          NA           NA      288.5               NA
# 581             Reuniclus          NA           NA      118.5               NA
# 582                Rhydon          NA           NA      264.5               NA
# 583               Rhyhorn          NA           NA      453.5               NA
# 584             Rhyperior          NA           NA      453.5               NA
# 585              Ribombee          NA           NA      275.5               NA
# 586                 Riolu          NA           NA      199.5               NA
# 587              Rockruff          NA           NA      453.5               NA
# 588            Roggenrola        39.5         44.0      733.5               NA
# 589               Roselia          NA           NA      467.0               NA
# 590              Roserade          NA           NA      148.5               NA
# 591                 Rotom          NA           NA      198.0               NA
# 592                Rowlet        17.5         18.5      145.0               NA
# 593               Rufflet          NA           NA      704.0               NA
# 594               Sableye          NA           NA       59.0               NA
# 595             Salamence          NA           NA       65.0               NA
# 596              Salandit          NA           NA      625.5               NA
# 597              Salazzle          NA           NA      320.5               NA
# 598              Samurott          NA           NA      193.5               NA
# 599               Sandile          NA           NA      494.5               NA
# 600             Sandshrew          NA           NA       69.0               NA
# 601             Sandslash          NA           NA       79.0               NA
# 602             Sandygast          NA           NA      704.0               NA
# 603                  Sawk          NA           NA      648.0               NA
# 604              Sawsbuck          NA           NA      330.0               NA
# 605            Scatterbug          NA           NA      783.5               NA
# 606              Sceptile         4.0         37.0       34.0               NA
# ...
# 631              Shieldon          NA           NA      673.0               NA
# 632               Shiftry          NA           NA      356.5               NA
# 633             Shiinotic          NA           NA      583.5               NA
# 634                 Shinx          NA           NA      103.0               NA
# 635             Shroomish          NA           NA      376.0               NA
# 636               Shuckle          NA           NA       77.0               NA
# 637               Shuppet          NA           NA      547.0               NA
# 638              Sigilyph          NA           NA      261.0               NA
# 639               Silcoon          NA           NA      807.5               NA
# 640              Silvally          NA           NA      330.0               NA
# 641              Simipour          NA           NA      733.5               NA
# 642              Simisage          NA           NA      704.0               NA
# 643              Simisear          NA           NA      625.5               NA
# 644              Skarmory          NA           NA       94.0               NA
# 645            Skeledirge          NA           NA         NA             29.0
# 646                Skiddo          NA           NA      514.0               NA
# 647              Skiploom          NA           NA      757.5               NA
# 648                Skitty          NA           NA      177.5               NA
# 649               Skorupi          NA           NA      801.5               NA
# 650                Skrelp          NA           NA      704.0               NA
# 651              Skuntank          NA           NA      504.0               NA
# 652               Slaking          NA           NA      191.0               NA
# 653               Slakoth          NA           NA      410.5               NA
# 654               Sliggoo          NA           NA      648.0               NA
# 655          Slither Wing          NA           NA         NA              8.0
# 656               Slowbro          NA           NA      169.5               NA
# 657              Slowking          NA           NA      252.5               NA
# 658              Slowpoke          NA           NA      110.0               NA
# 659                Slugma          NA           NA      529.5               NA
# 660              Slurpuff          NA           NA      437.5               NA
# 661              Smeargle          NA           NA      223.0               NA
# 662              Smoochum          NA           NA      704.0               NA
# 663               Sneasel          NA           NA      128.0               NA
# 664                 Snivy        22.5         30.5      203.5               NA
# 665                  Snom          NA           NA         NA             34.0
# 666               Snorlax        22.5          8.0       19.0               NA
# 667               Snorunt          NA           NA      376.0               NA
# 668                Snover          NA           NA      583.5               NA
# 669              Snubbull          NA           NA      437.5               NA
# 670              Solgaleo          NA           NA      547.0               NA
# 671               Solosis          NA           NA      625.5               NA
# 672               Solrock          NA           NA      673.0               NA
# 673               Spearow          NA           NA      783.5               NA
# 674                Spewpa          NA           NA      673.0               NA
# 675                Spheal          NA           NA      154.0               NA
# 676              Spinarak          NA           NA      564.0               NA
# 677                Spinda          NA           NA      288.5               NA
# 678             Spiritomb          NA           NA      303.5               NA
# 679                Spoink          NA           NA      320.5               NA
# 680            Sprigatito          NA           NA         NA             14.0
# 681              Spritzee          NA           NA      757.5               NA
# 682              Squirtle        17.5         18.5       14.0               NA
# 683             Stakataka          NA           NA      529.5               NA
# 684              Stantler          NA           NA      437.5               NA
# 685             Staraptor        13.5         40.5       89.0               NA
# 686              Staravia          NA           NA      648.0               NA
# 687                Starly          NA           NA      514.0               NA
# 688               Starmie          NA           NA      120.5               NA
# 689                Staryu          NA           NA      437.5               NA
# 690               Steelix          NA           NA      136.5               NA
# 691               Steenee          NA           NA      757.5               NA
# 692             Stoutland          NA           NA      376.0               NA
# 693               Stufful          NA           NA      564.0               NA
# 694              Stunfisk          NA           NA      376.0               NA
# 695                Stunky          NA           NA      673.0               NA
# 696             Sudowoodo          NA           NA      210.0               NA
# 697               Suicune          NA           NA       90.0               NA
# 698              Sunflora          NA           NA      547.0               NA
# 699               Sunkern          NA           NA      514.0               NA
# 700               Surskit          NA           NA      423.5               NA
# 701                Swablu          NA           NA      393.0               NA
# 702              Swadloon          NA           NA      564.0               NA
# 703                Swalot          NA           NA      423.5               NA
# 704              Swampert          NA           NA       29.0               NA
# 705                Swanna          NA           NA      704.0               NA
# 706               Swellow        13.5         28.5      320.5               NA
# 707                Swinub          NA           NA      283.0               NA
# 708               Swirlix          NA           NA      604.5               NA
# 709               Swoobat          NA           NA      547.0               NA
# 710               Sylveon          NA           NA       48.0              7.0
# 711               Taillow          NA           NA      625.5               NA
# 712            Talonflame        13.5         40.5      339.5               NA
# 713               Tangela          NA           NA      248.0               NA
# 714             Tangrowth          NA           NA      467.0               NA
# 715             Tapu-Bulu          NA           NA      783.5               NA
# 716             Tapu-Fini          NA           NA      783.5               NA
# 717             Tapu-Koko          NA           NA      583.5               NA
# 718             Tapu-Lele          NA           NA      733.5               NA
# 719  Tastugiri Curly Form          NA           NA         NA              6.0
# 720 Tastugiri Droopy Form          NA           NA         NA             44.0
# 721                Tauros        47.0         47.0      226.0               NA
# 722             Teddiursa          NA           NA      279.0               NA
# 723             Tentacool          NA           NA      604.5               NA
# 724            Tentacruel          NA           NA      348.0               NA
# 725                 Tepig          NA           NA      339.5               NA
# 726             Terrakion          NA           NA      757.5               NA
# 727                 Throh          NA           NA      604.5               NA
# 728             Thundurus          NA           NA      733.5               NA
# 729               Timburr          NA           NA      757.5               NA
# 730              Tinkaton          NA           NA         NA              1.0
# 731              Tirtouga          NA           NA      733.5               NA
# 732            Togedemaru          NA           NA      604.5               NA
# 733              Togekiss          NA           NA       81.0               NA
# 734                Togepi          NA           NA      185.0               NA
# 735               Togetic          NA           NA      437.5               NA
# 736               Torchic          NA           NA      126.0               NA
# 737               Torkoal        25.5         36.0      294.5               NA
# 738              Tornadus          NA           NA      783.5               NA
# 739              Torracat          NA           NA      583.5               NA
# 740              Torterra         9.0         35.0       20.0               NA
# 741              Totodile        22.5         23.0       42.0               NA
# 742             Toucannon          NA           NA      583.5               NA
# 743               Toxapex          NA           NA      303.5               NA
# 744             Toxicroak          NA           NA      158.5               NA
# 745             Tranquill          NA           NA      733.5               NA
# 746              Trapinch          NA           NA      423.5               NA
# 747               Treecko          NA           NA       95.0               NA
# 748             Trevenant          NA           NA      356.5               NA
# 749               Tropius          NA           NA      110.0               NA
# 750              Trubbish          NA           NA      233.0               NA
# 751              Trumbeak          NA           NA      801.5               NA
# 752              Tsareena          NA           NA      393.0               NA
# 753            Turtonator          NA           NA      673.0               NA
# 754               Turtwig          NA           NA       67.0               NA
# 755               Tympole          NA           NA      673.0               NA
# 756                Tynamo          NA           NA      673.0               NA
# 757             Type-Null          NA           NA      583.5               NA
# 758            Typhlosion          NA           NA       12.0               NA
# 759             Tyranitar          NA           NA       17.0             50.0
# 760             Tyrantrum          NA           NA      180.0               NA
# 761               Tyrogue          NA           NA      704.0               NA
# 762                Tyrunt          NA           NA      564.0               NA
# 763               Umbreon          NA           NA        6.0             16.0
# 764              Unfezant        39.5         15.0      704.0               NA
# 765                 Unown          NA           NA      478.5               NA
# 766              Ursaring          NA           NA      311.5               NA
# 767                  Uxie          NA           NA      757.5               NA
# 768             Vanillish          NA           NA      673.0               NA
# 769             Vanillite          NA           NA      529.5               NA
# 770             Vanilluxe          NA           NA      356.5               NA
# 771              Vaporeon          NA           NA       52.0               NA
# 772              Venipede          NA           NA      783.5               NA
# 773              Venomoth          NA           NA      467.0               NA
# 774               Venonat          NA           NA      376.0               NA
# 775              Venusaur          NA           NA      101.0               NA
# 776             Vespiquen          NA           NA      386.0               NA
# 777               Vibrava          NA           NA      494.5               NA
# 778               Victini          NA           NA      142.5               NA
# 779            Victreebel          NA           NA      467.0               NA
# 780              Vigoroth          NA           NA      604.5               NA
# 781              Vikavolt          NA           NA      547.0               NA
# 782             Vileplume          NA           NA      195.0               NA
# 783              Virizion          NA           NA      733.5               NA
# 784              Vivillon          NA           NA      564.0               NA
# 785               Volbeat          NA           NA      604.5               NA
# 786             Volcanion          NA           NA      704.0               NA
# 787             Volcarona          NA           NA       45.0             24.0
# 788               Voltorb          NA           NA      547.0               NA
# 789               Vullaby          NA           NA      757.5               NA
# 790                Vulpix          NA           NA       39.0               NA
# 791               Wailmer          NA           NA      478.5               NA
# 792               Wailord          NA           NA      148.5               NA
# 793               Walrein          NA           NA      320.5               NA
# 794             Wartortle          NA           NA       96.0               NA
# 795               Watchog          NA           NA      733.5               NA
# 796               Weavile          NA           NA       71.5               NA
# 797                Weedle          NA           NA      453.5               NA
# 798            Weepinbell          NA           NA      547.0               NA
# 799               Weezing          NA           NA      238.5               NA
# 800            Whimsicott          NA           NA       91.0               NA
# 801            Whirlipede          NA           NA      704.0               NA
# 802              Whiscash          NA           NA      410.5               NA
# 803               Whismur          NA           NA      704.0               NA
# 804            Wigglytuff          NA           NA      311.5               NA
# 805                Wimpod          NA           NA      757.5               NA
# 806               Wingull          NA           NA      478.5               NA
# 807            Wishiwashi          NA           NA      704.0               NA
# 808             Wobbuffet          NA           NA      169.5               NA
# 809                Woobat          NA           NA      583.5               NA
# 810                Wooper          NA           NA      122.0               NA
# 811              Wormadam          NA           NA      733.5               NA
# 812               Wurmple          NA           NA      547.0               NA
# 813                Wynaut          NA           NA      648.0               NA
# 814                  Xatu          NA           NA      238.5               NA
# 815               Xerneas          NA           NA      437.5               NA
# 816             Xurkitree          NA           NA      437.5               NA
# 817                Yamask          NA           NA      733.5               NA
# 818                 Yanma          NA           NA      423.5               NA
# 819               Yanmega          NA           NA      283.0               NA
# 820               Yungoos          NA           NA      807.5               NA
# 821               Yveltal          NA           NA      303.5               NA
# 822              Zangoose          NA           NA      129.0               NA
# 823                Zapdos          NA           NA      106.0               NA
# 824             Zebstrika          NA           NA      410.5               NA
# 825                Zekrom          NA           NA      283.0               NA
# 826               Zeraora          NA           NA      485.5               NA
# 827             Zigzagoon          NA           NA      219.5               NA
# 828               Zoroark          NA           NA       83.0             49.0
# 829                 Zorua          NA           NA      158.5             47.0
# 830                 Zubat          NA           NA      294.5               NA
# 831              Zweilous          NA           NA      733.5               NA
# 832               Zygarde          NA           NA      564.0               NA

# %%
# Calculate the ranking scores for battles
battle_score <- ifelse(is.na(new_dataset$battle_rank), 0,
                       ifelse(new_dataset$battle_rank <= 5, 50,
                              ifelse(new_dataset$battle_rank <= 10, 40,
                                     ifelse(new_dataset$battle_rank <= 20, 30,
                                            ifelse(new_dataset$battle_rank <= 50, 20,
                                                   ifelse(new_dataset$battle_rank <= 100, 10, 5))))))

# Calculate the ranking scores for win percentage
win_pct_score <- ifelse(is.na(new_dataset$win_pct_rank), 0,
                         ifelse(new_dataset$win_pct_rank <= 5, 50,
                                ifelse(new_dataset$win_pct_rank <= 10, 40,
                                       ifelse(new_dataset$win_pct_rank <= 20, 30,
                                              ifelse(new_dataset$win_pct_rank <= 30, 20,
                                                     ifelse(new_dataset$win_pct_rank <= 100, 10, 5))))))

# Calculate the ranking scores for Reddit survey
reddit_score <- ifelse(is.na(new_dataset$votes_rank), 0,
                        ifelse(new_dataset$votes_rank <= 5, 50,
                               ifelse(new_dataset$votes_rank <= 10, 40,
                                      ifelse(new_dataset$votes_rank <= 20, 30,
                                             ifelse(new_dataset$votes_rank <= 50, 20,
                                                    ifelse(new_dataset$votes_rank <= 100, 10, 5))))))

# Calculate the ranking scores for Japan survey
japan_score <- ifelse(is.na(new_dataset$japan_votes_rank), 0,
                       ifelse(new_dataset$japan_votes_rank == 1, 70,
                              ifelse(new_dataset$japan_votes_rank <= 3, 65,
                                     ifelse(new_dataset$japan_votes_rank <= 5, 60,
                                            ifelse(new_dataset$japan_votes_rank <= 10, 50,
                                                   ifelse(new_dataset$japan_votes_rank <= 20, 55,
                                                          ifelse(new_dataset$japan_votes_rank <= 30, 52,
                                                                 ifelse(new_dataset$japan_votes_rank <= 50, 51,
                                                                        ifelse(new_dataset$japan_votes_rank <= 100, 1, 0)))))))))

# Calculate the aggregated score
aggregated_score <- battle_score + win_pct_score + reddit_score + japan_score

# Combine Pokémon data with aggregated score
pokemon_scores <- data.frame(name = new_dataset$name, score = aggregated_score)

# Sort the Pokémon based on the aggregated score
sorted_pokemon <- pokemon_scores[order(pokemon_scores$score, decreasing = TRUE), ]

# Select the top-ranked Pokémon as recommendations
top_recommendations <- head(sorted_pokemon, 25) # <-- Modify this number to modify the recommendations table

# %%
# Initialize an empty data frame to store the details
pokemon_details <- data.frame()

# Iterate over each Pokemon in the top_recommendations list
for (pokemon in top_recommendations$name) {
  # Get the details for the current Pokemon
  pokemon_details <- rbind(pokemon_details, new_dataset[new_dataset$name == pokemon, ])}

# Create a new data frame with the desired columns
pokemon_table <- data.frame(
  pokemon_name = pokemon_details$name,
  battle_rank = ifelse(!is.na(pokemon_details$battle_rank), paste0("#", pokemon_details$battle_rank), "-"),
  win_pct_rank = ifelse(!is.na(pokemon_details$win_pct_rank), paste0("#", pokemon_details$win_pct_rank), "-"),
  reddit_survey = ifelse(!is.na(pokemon_details$votes_rank), paste0("#", pokemon_details$votes_rank), "-"),
  japan_survey = ifelse(!is.na(pokemon_details$japan_votes_rank), 
                                     paste0("#", pokemon_details$japan_votes_rank), 
                                     "-"),
  stringsAsFactors = FALSE)

# %% [markdown]
# ## Supporting Visualizations and Key Findings

# %% [markdown]
# In this section, the objective is to delve into the data and gain insights into the top-performing Pokemon across different categories and datasets.

# %%
# Plotting Top 15 Ash pokemon by win percentage

# Preparing the data
top_win_pct <- ash_pokemon %>%
  select(name, battles, wins, win_pct, type) %>%
  arrange(desc(win_pct)) %>%
  top_n(15, win_pct)

# Plotting the data
ggplot(top_win_pct, aes(x=win_pct, y=reorder(name, win_pct), fill=type)) +
  geom_bar(stat= 'identity') +
  geom_text(aes(label=paste0(round(win_pct*100,1), "%")), hjust = -0.1, size = 3, position = position_stack(vjust = 0.5)) +
  scale_x_continuous(limits = c(0, 1), expand = c(0, 0), labels = scales::percent_format(accuracy = 1)) +
  xlab('Win percentage') +
  ylab('Pokemon name') +
  ggtitle('Top 15 pokemon by win percentage') +
  scale_fill_manual(values = type_colors) +
  theme(axis.text.x = element_text(size = 10), axis.text.y = element_text(size = 8), plot.title = element_text(hjust = 0.5))
# Out:
# plot without title

# %%
# Top 15 Ash Pokemon by number of battles
top_battles_count <- ash_pokemon %>%
	select(name, battles) %>%
	arrange(desc(battles)) %>%
	top_n(15, battles)
top_battles_count
# Out:
#    name       battles
# 1  Pikachu    538
# 2  Greninja    55
# 3  Bulbasaur   52
# 4  Sceptile    48
# 5  Charizard   47
# 6  Corphish    47
# 7  Infernape   46
# 8  Buizel      43
# 9  Torterra    41
# 10 Bayleef     38
# 11 Pignite     32
# 12 Swellow     26
# 13 Hawlucha    26
# 14 Staraptor   26
# 15 Talonflame  26

# %% [markdown]
# After inspecting the top 15 Pokemon by number of battles, it becomes evident that Pikachu stands out significantly, surpassing all other Pokemon in terms of battle count. To provide a more meaningful visualization, a scatter plot comparing the number of battles with the win percentage was used. Additionally, to better capture the comparative scale of battle numbers, a log scale was applied for the number of battles.

# %%
# Plotting Top number of battles vs Win Percentage

# Sorting the data by win percentage and battles
top_win_pct <- head(ash_pokemon[order(ash_pokemon$win_pct, decreasing = TRUE), ], 10)
top_battles <- head(ash_pokemon[order(ash_pokemon$battles, decreasing = TRUE), ], 10)

# Plotting the scatter plot with logarithmic scale on the x-axis and text labels
ggplot(ash_pokemon, aes(x = battles, y = win_pct, color = type)) +
  geom_point(size = 4) +
  scale_color_manual(values = type_colors) +
  scale_x_log10() +
  xlab('Number of Battles (log scale)') +
  ylab('Win Percentage') +
  ggtitle('Ash Pokemon: Battles vs Win Percentage') +
  geom_text(data = top_win_pct, aes(label = name), hjust = 1.2, vjust = 0) +
  geom_text(data = top_battles, aes(label = name), hjust = 1.2, vjust = 0) +
theme(plot.title = element_text(hjust = 0.5))
# Out:
# plot without title

# %%
# Plotting the top 15 most voted pokemon in the Reddit Survey

# Merge the reddit_survey_data with pokedex_data to get type information
merged_data <- merge(reddit_survey_data, pokedex_data[, c("name", "type_1")], by = "name", all.x = TRUE)

# Filter the merged data to include only the top 15 Pokémon
top_15 <- head(merged_data[order(merged_data$votes, decreasing = TRUE), ], 15)

# Plot the top 15 Pokémon with colors based on their types
ggplot(top_15, aes(x = reorder(name, votes), y = votes, fill = type_1)) +
  geom_bar(stat = "identity") +
  geom_text(aes(label = votes), hjust = -0.1, size = 3, position = position_stack(vjust = 0.5)) +
  coord_flip() +
  labs(x = "Pokemon", y = "Votes", title = "Top 15 Pokemon by Votes in Reddit Survey") +
  scale_fill_manual(values = type_colors) +
  theme(plot.title = element_text(hjust = 0.5))
# Out:
# plot without title

# %%
# Plotting the top 15 most voted pokemon in the Japan Survey

# Merge the reddit_survey_data with pokedex_data to get type information
merged_data <- merge(japan_survey_data, pokedex_data[, c("name", "type_1")], by = "name", all.x = TRUE)

# Filter the merged data to include only the top 15 Pokémon
top_15 <- head(merged_data[order(merged_data$votes, decreasing = TRUE), ], 15)

# Plot the top 15 Pokémon with colors based on their types
ggplot(top_15, aes(x = reorder(name, votes), y = votes, fill = type_1)) +
  geom_bar(stat = "identity") +
  geom_text(aes(label = votes), hjust = -0.1, size = 3, position = position_stack(vjust = 0.5)) +
  coord_flip() +
  labs(x = "Pokémon", y = "Votes", title = "Top 15 Pokemon by Votes in Japan Survey") +
  scale_fill_manual(values = type_colors) +
  theme(axis.text.x = element_text(angle = 45, hjust = 1), plot.title = element_text(hjust = 0.5))
# Out:
# plot without title

# %% [markdown]
# ## Major Insights and Actionable Conclusions
#
# 1. Data-driven Recommendation List: By implementing a balanced scoring system, I have created a data-driven recommendation list for the starting merchandise lineup. This approach ensures that any decisions are not based on personal biases or arbitrary choices. Instead, we can rely on comprehensive data analysis to identify the most suitable Pokemon based on their performance, popularity, and fan preferences. This data-driven approach adds credibility and increases the likelihood of selecting Pokemon that resonate with potential customers.
# 2. Enduring Popularity of Gen 1 Pokemon: One interesting observation is the presence of several Pokemon from Generation 1 in our recommendation list, even in the most recent data source, the Japan survey. This highlights the continued favoritism and enduring popularity of these iconic Pokemon among fans. Considering the sustained appeal of Gen 1 Pokemon, it would be prudent to include them prominently in the merchandise lineup to cater to the nostalgia and emotional connection that fans have with these beloved characters.
# 3. Maximizing Revenue Potential: By leveraging the insights from our analysis, we can strategically maximize the revenue potential of the starting merchandise lineup. By selecting Pokemon that not only have high rankings but also possess a combination of competitive strength, fan popularity, and cultural significance, we can create a lineup that appeals to a wide range of fans. This approach taps into various market segments, catering to both hardcore competitive players and casual fans seeking nostalgic experiences.
# 4. Continuous Data Monitoring: To stay up-to-date with evolving fan preferences and trends, it is crucial to establish a system for continuous data monitoring. Regularly updating our dataset with new survey results, social media sentiment analysis, and sales data will enable us to adapt our merchandise lineup accordingly. This iterative approach ensures that our selections remain relevant and aligned with the ever-changing dynamics of the Pokemon fandom.
#
# Incorporating these major insights and actionable conclusions will guide us in making informed decisions and developing a merchandise lineup that combines data-driven recommendations, enduring fan favorites, and revenue-maximizing strategies.

# %%
# Final recommendation table
pokemon_table
# Out:
#    pokemon_name battle_rank win_pct_rank reddit_survey japan_survey
# 1  Pikachu      #1          #1           #44           #31
# 2  Charizard    #5.5        #21          #1            #25
# 3  Bulbasaur    #3          #12          #4            -
# 4  Greninja     #2          #4           #66           -
# 5  Infernape    #7          #9           #18           -
# 6  Gengar       -           -            #2            #13
# 7  Arcanine     -           -            #3            #36
# 8  Bayleef      #10         #5           #196.5        -
# 9  Gardevoir    -           -            #8            #10.5
# 10 Umbreon      -           -            #6            #16
# 11 Eevee        -           -            #9            #28
# 12 Dragonite    -           -            #10           #46
# 13 Lucario      -           -            #7            #9
# 14 Snorlax      #22.5       #8           #19           -
# 15 Squirtle     #17.5       #18.5        #14           -
# 16 Ampharos     -           -            #13           #45
# 17 Tyranitar    -           -            #17           #50
# 18 Sceptile     #4          #37          #34           -
# 19 Torterra     #9          #35          #20           -
# 20 Goodra       #28         #2           #151          -
# 21 Incineroar   #20         #6.5         #214.5        -
# 22 Lycanroc     #17.5       #10          #142.5        -
# 23 Mimikyu      -           -            #47           #10.5
# 24 Naganadel    #42.5       #3           #604.5        -
# 25 Garchomp     -           -            #24.5         #22

# %% [markdown]
# ## Enhancing the Analysis: Additional Recommendations for Consideration
# In addition to the key findings and insights obtained from the analysis, there are several avenues for further exploration and enhancement of the project.
#
# Ideas for Further Analysis and Enhancement:
#
# - Utilize Pokemon Types and Generations: Explore the potential of utilizing the Pokemon types and generations data to create more rankings for the Reddit survey. By incorporating these variables into the scoring system, we can enhance the analysis and provide more nuanced recommendations based on generational popularity and type preferences, also creating ranks based on the most voted Pokemon for each type, allowing us to provide specialized recommendations tailored to fans' specific type affinities.
# - Leverage Weight and Height Data: By utilizing this information, we can explore product opportunities that align with the physical characteristics of different Pokemon. For instance, by focusing on Pokemon with larger sizes, such as those with significant weight or towering heights, we can propose products like oversized plushies, larger posters, or collectible figurines. Incorporating weight and height data allows us to cater to the preferences of fans who appreciate Pokemon with impressive physical proportions, providing them with merchandise that accurately represents their favorite characters in a visually appealing way.
# - Developing a Well-Balanced Scoring System: To determine the final rankings, it is recommended to develop a scoring system that considers various factors, from data already present but also anything else that can be added later. Finding the right balance of factors will ensure a fair and comprehensive evaluation of each Pokemon. This scoring system will serve as a valuable tool for ranking and selecting the Pokemon for the expanding the merchandise lineup.
# - Obtain Updated Data for Ash Ketchum's Teams: To further strengthen our analysis and provide a comprehensive evaluation of Pokemon suitability, it is recommended to acquire an updated dataset that includes information on the Pokemon that have been part of Ash Ketchum's teams beyond Generation 7. By incorporating data from the more recent Pokemon series, we can capture the evolving dynamics of Ash's team composition and factor in the popularity and performance of these Pokemon in our recommendation list.
#
#
# The following recommendations offer valuable opportunities to expand our understanding and refine the selection process for Pokemon merchandise.
#
# - Customer Surveys and Feedback Analysis: Gather customer feedback through surveys or focus groups to understand their preferences, expectations, and desired features in Pokemon merchandise. Analyze the collected data to uncover additional insights and fine-tune the selection.
# - Exploring Trainer Profiles: By delving deeper into the world of Pokemon animated series and games, we can uncover valuable insights by investigating the popularity of trainers. Analyzing the pokemon teams of more trainers allows us to draw inspiration and gather further suggestions for our Pokemon merchandise lineup.
# - Incorporate Trainer-Themed Collections: Expanding from the previous point, we could consider creating trainer-themed collections based on popular trainers. For instance, we could group together Pokemon plushies that are associated with a specific trainer or offer sets that recreate their team compositions. This approach allows fans to collect and display plushies that represent their favorite trainers, further enhancing the emotional connection and appeal of the merchandise.
